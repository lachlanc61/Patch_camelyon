# %%
# %load core.py

# %%
# %load core.py

import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow_datasets as tfds

from tensorflow import keras
from keras import Sequential 

import src.utils as utils
import src.tfmodel as tfmodel
import src.vis as vis

"""
Practice project - histology

"""
#-----------------------------------
#Vars
#-----------------------------------

CONFIG_FILE='config.yaml'
DSETNAME='patch_camelyon'
#-----------------------------------
#INITIALISE
#-----------------------------------

config=utils.readcfg(CONFIG_FILE)

wdirname=config['wdirname']
odirname=config['odirname']
batchsize=config['batchsize']

spath, wdir, odir, checkpoint_path, checkpoint_dir = utils.initialise(config)

#-----------------------------------
#MAIN START
#-----------------------------------

dtrain, dval, dtest, dsinfo = utils.datainit(config, DSETNAME)

timg, tlabels, vimg, vlabels, testimg, testlabels = utils.batchcheck(dtrain, dval, dtest, batchsize)


if config['PREPLOT']:
    vis.preplot(config)

#we are overfitting pretty heavily, try regularisation
l2reg=tf.keras.regularizers.L2(config['lamda'])
#kernel_regularizer=l2reg
  #not great, slow and not a big improvement, leave it out for now


model = tfmodel.build(config)

model, fitlog = tfmodel.train(model, dtrain, dval, config, checkpoint_path)

vis.layerplot(config, model, timg, tlabels, odir)

print("CLEAN EXIT")
exit()
# Out:
# script path: /home/lachlan/CODEBASE/Patch_camelyon
# working path: /home/lachlan/CODEBASE/Patch_camelyon/train
# output path: /home/lachlan/CODEBASE/Patch_camelyon/out
# cp: /home/lachlan/CODEBASE/Patch_camelyon/train/cp-{epoch:04d}.ckpt
# cp: /home/lachlan/CODEBASE/Patch_camelyon/train
# ---------------
# python version: 3.7.13 (default, Sep  4 2022, 13:19:50)
# [GCC 9.4.0]
# tensorflow version: 2.9.2
# GPU: True
# ---------------
# 2022-10-12 21:08:03.375421: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-12 21:08:03.377186: I tensorflow/c/logging.cc:34] DirectML: creating device on adapter 0 (NVIDIA GeForce RTX 2070)
# 2022-10-12 21:08:04.146309: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-10-12 21:08:04.146355: W tensorflow/core/common_runtime/pluggable_device/pluggable_device_bfc_allocator.cc:28] Overriding allow_growth setting because force_memory_growth was requested by the device.
# 2022-10-12 21:08:04.146378: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6827 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# labelshape: (128,)
# imgshape: (128, 96, 96, 3)
# batch size: 128
# 2022-10-12 21:08:06.181522: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-10-12 21:08:06.181586: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6827 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2022-10-12 21:08:06.182293: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  efficientnetb4 (Functional)  (None, 3, 3, 1792)       17673823
#
#  global_average_pooling2d (G  (None, 1792)             0
#  lobalAveragePooling2D)
#
#  dense1 (Dense)              (None, 128)               229504
#
#  dropout (Dropout)           (None, 128)               0
#
#  output (Dense)              (None, 1)                 129
#
# =================================================================
# Total params: 17,903,456
# Trainable params: 229,633
# Non-trainable params: 17,673,823
# _________________________________________________________________
# Epoch 1/100
# 2022-10-12 21:08:15.357664: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2022-10-12 21:08:15.543940: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block1a_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.545225: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block1b_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.545965: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatVecPermute' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block2a_dwconv_pad/Pad-1-DataFormatVecPermuteNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='XLA_CPU_JIT'; label='host'; T in [DT_INT32, DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.546476: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block2a_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.547110: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block2b_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.547784: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block2c_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.548885: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block2d_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.550048: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatVecPermute' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block3a_dwconv_pad/Pad-1-DataFormatVecPermuteNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='XLA_CPU_JIT'; label='host'; T in [DT_INT32, DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.551291: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block3a_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.552410: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block3b_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.553239: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block3c_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.554016: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block3d_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.554815: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatVecPermute' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block4a_dwconv_pad/Pad-1-DataFormatVecPermuteNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='XLA_CPU_JIT'; label='host'; T in [DT_INT32, DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.555533: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block4a_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.556726: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block4b_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.557660: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block4c_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.558724: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block4d_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.559387: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block4e_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.560018: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block4f_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.560819: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block5a_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.561644: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block5b_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.563025: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block5c_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.564099: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block5d_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.564852: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block5e_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.565508: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block5f_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.566063: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatVecPermute' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block6a_dwconv_pad/Pad-1-DataFormatVecPermuteNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='XLA_CPU_JIT'; label='host'; T in [DT_INT32, DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.566517: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block6a_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.567343: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block6b_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.568794: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block6c_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.569720: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block6d_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.570465: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block6e_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.571142: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block6f_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.571849: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block6g_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.572558: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block6h_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.573561: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block7a_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.574890: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/efficientnetb4/block7b_se_squeeze/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:15.575808: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered 'DataFormatDimMap' OpKernel for GPU devices compatible with node {{node model/global_average_pooling2d/Mean-1-DataFormatDimMapNHWCToNCHW-LayoutOptimizer}}
# 	.  Registered:  device='XLA_CPU_JIT'; T in [DT_INT32, DT_INT64]
#   device='GPU'; T in [DT_INT64]
#   device='GPU'; T in [DT_INT32]
#   device='CPU'; label='host'; T in [DT_INT64]
#   device='CPU'; label='host'; T in [DT_INT32]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_INT32]
#
# 2022-10-12 21:08:16.200842: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-10-12 21:08:16.200893: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6827 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2022-10-12 21:08:16.201063: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-10-12 21:08:16.201085: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6827 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2022-10-12 21:08:16.201216: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-10-12 21:08:16.201228: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6827 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
#   95/2048 [>.............................] - ETA: 4:25 - loss: 0.6951 - acc: 0.5376
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1550/2481935461.py in <module>
#      56 model = tfmodel.build(config)
#      57
# ---> 58 model, fitlog = tfmodel.train(model, dtrain, dval, config, checkpoint_path)
#      59
#      60 vis.layerplot(config, model, timg, tlabels, odir)
#
# ~/CODEBASE/Patch_camelyon/src/tfmodel.py in train(model, dtrain, dval, config, checkpoint_path)
#     171             validation_freq = 1,
#     172             callbacks=[stopcond,cp_callback],
# --> 173             verbose=1
#     174         )
#     175
#
# ~/.pyenv/versions/venv_patchcam/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/.pyenv/versions/venv_patchcam/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1407                 _r=1):
#    1408               callbacks.on_train_batch_begin(step)
# -> 1409               tmp_logs = self.train_function(iterator)
#    1410               if data_handler.should_sync:
#    1411                 context.async_wait()
#
# ~/.pyenv/versions/venv_patchcam/lib/python3.7/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/.pyenv/versions/venv_patchcam/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/.pyenv/versions/venv_patchcam/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# ~/.pyenv/versions/venv_patchcam/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2453     return graph_function._call_flat(
# -> 2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2455
#    2456   @property
#
# ~/.pyenv/versions/venv_patchcam/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1859       # No tape is watching; skip to running the function.
#    1860       return self._build_call_outputs(self._inference_function.call(
# -> 1861           ctx, args, cancellation_manager=cancellation_manager))
#    1862     forward_backward = self._select_forward_and_backward_functions(
#    1863         args,
#
# ~/.pyenv/versions/venv_patchcam/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     500               inputs=args,
#     501               attrs=attrs,
# --> 502               ctx=ctx)
#     503         else:
#     504           outputs = execute.execute_with_cancellation(
#
# ~/.pyenv/versions/venv_patchcam/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:
